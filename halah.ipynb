# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./input/stresstest.csv')

# %%
data.head()
# Out:
#                   Modul                       Nama         Role  \
# 0  Ekspektasi & Realita  rezzy Yolanda Wulandhari            SM
# 1                   NaN                        NaN  Desainer UX
# 2                   NaN              Mahirza Avil   Desainer UI
# 3                   NaN                        NaN  Desainer UI
# 4                   NaN           Viananda Andrias  Animator 2D
#
#    sprint_1_backlog  sprint_1_nps  sprint_1_percent_wh  sprint_1_real_wh  \
# 0               0.0           2.0                  3.0              50.0
# 1               0.0           0.0                  0.0               NaN
# 2               0.0           0.0                  0.0               NaN
# 3               0.0           0.0                  0.0               NaN
# 4               0.0           2.0                  1.5              25.0
#
#    sprint_1_rating sprint_1_fee  sprint_2_backlog      ...       \
# 0              5.0      200,000               0.0      ...
# ...

# %%
data.describe()
# Out:
#        sprint_1_backlog  sprint_1_nps  sprint_1_percent_wh  sprint_1_real_wh  \
# count         85.000000     85.000000            85.000000         37.000000
# mean           0.423529      0.600000             0.861176         32.972973
# std            1.238052      0.889087             1.193544         17.096924
# min            0.000000     -0.750000             0.000000          5.000000
# 25%            0.000000      0.000000             0.000000         17.000000
# 50%            0.000000      0.000000             0.000000         31.000000
# 75%            0.000000      1.500000             1.680000         50.000000
# max            4.000000      3.000000             4.200000         70.000000
#
#        sprint_1_rating  sprint_2_backlog  sprint_2_nps  sprint_2_percent_wh  \
# count        85.000000         85.000000     85.000000            85.000000
# mean          1.795294          0.188235      0.924706             0.873882
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 21 columns):
# Modul                  14 non-null object
# Nama                   50 non-null object
# Role                   85 non-null object
# sprint_1_backlog       85 non-null float64
# sprint_1_nps           85 non-null float64
# sprint_1_percent_wh    85 non-null float64
# sprint_1_real_wh       37 non-null float64
# sprint_1_rating        85 non-null float64
# sprint_1_fee           40 non-null object
# sprint_2_backlog       85 non-null float64
# sprint_2_nps           85 non-null float64
# sprint_2_percent_wh    85 non-null float64
# sprint_2_real_wh       42 non-null float64
# sprint_2_rating        85 non-null float64
# sprint_2_fee           42 non-null object
# sprint_3_backlog       85 non-null float64
# sprint_3_nps           85 non-null float64
# sprint_3_percent_wh    85 non-null float64
# sprint_3_real_wh       11 non-null float64
# ...

# %%
data.head()
# Out:
#                   Modul                       Nama         Role  \
# 0  Ekspektasi & Realita  rezzy Yolanda Wulandhari            SM
# 1                   NaN                        NaN  Desainer UX
# 2                   NaN              Mahirza Avil   Desainer UI
# 3                   NaN                        NaN  Desainer UI
# 4                   NaN           Viananda Andrias  Animator 2D
#
#    sprint_1_backlog  sprint_1_nps  sprint_1_percent_wh  sprint_1_real_wh  \
# 0               0.0           2.0                  3.0              50.0
# 1               0.0           0.0                  0.0               NaN
# 2               0.0           0.0                  0.0               NaN
# 3               0.0           0.0                  0.0               NaN
# 4               0.0           2.0                  1.5              25.0
#
#    sprint_1_rating sprint_1_fee  sprint_2_backlog      ...       \
# 0              5.0      200,000               0.0      ...
# ...

# %%
data.corr()
# Out:
#                      sprint_1_backlog  sprint_1_nps  sprint_1_percent_wh  \
# sprint_1_backlog             1.000000     -0.038935            -0.056414
# sprint_1_nps                -0.038935      1.000000             0.555488
# sprint_1_percent_wh         -0.056414      0.555488             1.000000
# sprint_1_real_wh            -0.164598      0.014032             1.000000
# sprint_1_rating              0.399502      0.727937             0.782414
# sprint_2_backlog            -0.076472      0.084857             0.296637
# sprint_2_nps                -0.146478      0.800483             0.557501
# sprint_2_percent_wh         -0.132333      0.529070             0.797136
# sprint_2_real_wh             0.056422      0.066945             0.586038
# sprint_2_rating             -0.161589      0.668837             0.754876
# sprint_3_backlog            -0.132677      0.214145             0.143776
# sprint_3_nps                -0.126666      0.233663             0.202051
# ...

# %%
f,ax = plt.subplots(figsize=(20,20))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt='.3f', ax=ax)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
