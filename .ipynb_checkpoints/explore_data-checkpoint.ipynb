# %% [markdown]
# Pertama-tama, masukkan library yg akan membantu kita

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from subprocess import check_output
print(check_output(["ls", "./input"]).decode("utf8"))
# Out:
# combats.csv
# pokemon.csv
# tests.csv

# %%
data = pd.read_csv('./input/pokemon.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# name          799 non-null object
# type1         800 non-null object
# type2         414 non-null object
# hp            800 non-null int64
# attack        800 non-null int64
# defense       800 non-null int64
# specatk       800 non-null int64
# specdef       800 non-null int64
# speed         800 non-null int64
# generation    800 non-null int64
# legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %%
# lihat korelasi antar features
# tapi, correlation does not imply causation
# If they are both above their mean (or both below), then this will produce a positive number, 
# because a positive×positive=positive, and likewise a negative×negative=positive.

# min_periods : int, optional => Minimum number of observations required 

# correlations = data.corr() # default: pearson
# correlations = data.corr(method='spearman',min_periods=1)
# correlations =  data.corr(method='pearson',min_periods=1)
correlations = data.corr(method='kendall')

correlations
# Out:
#                    #        hp    attack   defense   specatk   specdef  \
# #           1.000000  0.082998  0.068928  0.079238  0.061706  0.052774
# hp          0.082998  1.000000  0.413993  0.324233  0.338039  0.357735
# attack      0.068928  0.413993  1.000000  0.369529  0.258397  0.223371
# defense     0.079238  0.324233  0.369529  1.000000  0.220791  0.451869
# specatk     0.061706  0.338039  0.258397  0.220791  1.000000  0.422981
# specdef     0.052774  0.357735  0.223371  0.451869  0.422981  1.000000
# speed       0.012898  0.180047  0.259124  0.063026  0.329196  0.222677
# generation  0.908018  0.060275  0.037858  0.041291  0.029021  0.013420
# legendary   0.126093  0.245886  0.261976  0.222471  0.308598  0.273571
#
#                speed  generation  legendary
# #           0.012898    0.908018   0.126093
# hp          0.180047    0.060275   0.245886
# attack      0.259124    0.037858   0.261976
# defense     0.063026    0.041291   0.222471
# specatk     0.329196    0.029021   0.308598
# specdef     0.222677    0.013420   0.273571
# speed       1.000000   -0.010233   0.259365
# generation -0.010233    1.000000   0.070160
# legendary   0.259365    0.070160   1.000000

# %%
# correlation map
# higher correlations are brighter
f,ax = plt.subplots(figsize=(20,20))
sns.heatmap(correlations, annot=True, linewidths=.5, fmt='.3f', ax=ax)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# print contoh 5 data dulu
data.head(20)
# Out:
#      #              name  type1   type2  hp  attack  defense  specatk  \
# 0    1         Bulbasaur  Grass  Poison  45      49       49       65
# 1    2           Ivysaur  Grass  Poison  60      62       63       80
# 2    3          Venusaur  Grass  Poison  80      82       83      100
# 3    4     Mega Venusaur  Grass  Poison  80     100      123      122
# 4    5        Charmander   Fire     NaN  39      52       43       60
# 5    6        Charmeleon   Fire     NaN  58      64       58       80
# 6    7         Charizard   Fire  Flying  78      84       78      109
# 7    8  Mega Charizard X   Fire  Dragon  78     130      111      130
# 8    9  Mega Charizard Y   Fire  Flying  78     104       78      159
# 9   10          Squirtle  Water     NaN  44      48       65       50
# 10  11         Wartortle  Water     NaN  59      63       80       65
# 11  12         Blastoise  Water     NaN  79      83      100       85
# 12  13    Mega Blastoise  Water     NaN  79     103      120      135
# 13  14          Caterpie    Bug     NaN  45      30       35       20
# 14  15           Metapod    Bug     NaN  50      20       55       25
# 15  16        Butterfree    Bug  Flying  60      45       50       90
# 16  17            Weedle    Bug  Poison  40      35       30       20
# 17  18            Kakuna    Bug  Poison  45      25       50       25
# 18  19          Beedrill    Bug  Poison  65      90       40       45
# 19  20     Mega Beedrill    Bug  Poison  65     150       40       15
#
#     specdef  speed  generation  legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 3       120     80           1      False
# 4        50     65           1      False
# 5        65     80           1      False
# 6        85    100           1      False
# 7        85    100           1      False
# 8       115    100           1      False
# 9        64     43           1      False
# 10       80     58           1      False
# 11      105     78           1      False
# 12      115     78           1      False
# 13       20     45           1      False
# 14       25     30           1      False
# 15       80     70           1      False
# 16       20     50           1      False
# 17       25     35           1      False
# 18       80     75           1      False
# 19       80    145           1      False

# %%
# lihat kolomnya ada apa aja di data yg kita punya
data.columns
# Out:
# Index(['#', 'name', 'type1', 'type2', 'hp', 'attack', 'defense', 'specatk',
#        'specdef', 'speed', 'generation', 'legendary'],
#       dtype='object')

# %% [markdown]
# # Plotting using Matplotlib

# %% [markdown]
# Matplotlib adalah sebuah library untuk ngulik visualisasi.

# %%
data.columns.values.tolist()
# Out:
# ['#',
#  'name',
#  'type1',
#  'type2',
#  'hp',
#  'attack',
#  'defense',
#  'specatk',
#  'specdef',
#  'speed',
#  'generation',
#  'legendary']

# %%
# Line Plot
# color = color, label = label, linewidth = width of line, alpha = opacity, grid = grid, linestyle = sytle of line
data.attack.plot(kind='line', color='g',label='Attack', linewidth=1,alpha=.5, grid=True,linestyle=':')
data.specatk.plot(kind='line', color='r',label='Special Attack',linewidth=1,alpha=.5, grid=True,linestyle='-')
plt.legend(loc='upper right') # put label in image
plt.xlabel('number of data')
plt.ylabel('value')
plt.title('attack & spec attack')
plt.show()

# %%
# scatter plot
# x = attack y = defense
data.plot(kind='scatter', x='attack',y='defense',alpha=.5, color='red')
plt.xlabel('Attack')
plt.ylabel('Defence')
plt.title('Attack Defense Scatter Plot')
# Out:
# Text(0.5,1,'Attack Defense Scatter Plot')

# %%
# histogram vis
data.attack.plot(kind='hist', bins = 50, figsize=(12,12))
plt.show()
