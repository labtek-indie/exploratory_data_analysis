# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")
from subprocess import check_output

print(check_output(["ls","../datasets"]).decode("utf8"))
# Out:
# UCI_Credit_Card.csv
# app-store-apple-data-set-10k-apps
# data.csv
# fifa-18-demo-player-dataset
# fifa-18-more-complete-player-dataset
# nyse
# sandp500
# sf-salaries
# speed-dating-experiment
# us-acs-mortgage-equity-loans-rent-statistics
# world-happiness-report
# world-university-rankings
# xAPI-Edu-Data.csv

# %%
data = pd.read_csv("../datasets/fifa-18-demo-player-dataset/CompleteDataset.csv")
data
# Out:
#        Unnamed: 0               Name  Age  \
# 0               0  Cristiano Ronaldo   32
# 1               1           L. Messi   30
# 2               2             Neymar   25
# 3               3          L. Suárez   30
# 4               4           M. Neuer   31
# 5               5     R. Lewandowski   28
# 6               6             De Gea   26
# 7               7          E. Hazard   26
# 8               8           T. Kroos   27
# 9               9         G. Higuaín   29
# 10             10       Sergio Ramos   31
# 11             11       K. De Bruyne   26
# 12             12        T. Courtois   25
# 13             13         A. Sánchez   28
# 14             14          L. Modrić   31
# 15             15            G. Bale   27
# 16             16          S. Agüero   29
# 17             17       G. Chiellini   32
# 18             18          G. Buffon   39
# 19             19          P. Dybala   23
# 20             20           J. Oblak   24
# ...

# %%
df1 = pd.DataFrame(data)
df1 = df1[["Name","Age", "Nationality", "Overall", "Potential", "Club"]]
df1.head()
# Out:
#                 Name  Age Nationality  Overall  Potential                 Club
# 0  Cristiano Ronaldo   32    Portugal       94         94       Real Madrid CF
# 1           L. Messi   30   Argentina       93         93         FC Barcelona
# 2             Neymar   25      Brazil       92         94  Paris Saint-Germain
# 3          L. Suárez   30     Uruguay       92         92         FC Barcelona
# 4           M. Neuer   31     Germany       92         92     FC Bayern Munich

# %%
df2 = pd.DataFrame(data)
df2 = df2.loc[:,"RB":"ST"]
df2.head()
# Out:
#      RB   RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  61.0  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  57.0  45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# 2  59.0  46.0  79.0  59.0  88.0  87.0  84.0  89.0  64.0  84.0
# 3  64.0  58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %%
# concat two dataframe to cleanup data into what we need only
cldat = pd.concat([df1, df2], axis=1, sort=False)
cldat.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  Cristiano Ronaldo   32    Portugal       94         94
# 1           L. Messi   30   Argentina       93         93
# 2             Neymar   25      Brazil       92         94
# 3          L. Suárez   30     Uruguay       92         92
# 4           M. Neuer   31     Germany       92         92
#
#                   Club    RB   RCB   RCM   RDM    RF    RM    RS    RW   RWB  \
# 0       Real Madrid CF  61.0  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0
# 1         FC Barcelona  57.0  45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0
# 2  Paris Saint-Germain  59.0  46.0  79.0  59.0  88.0  87.0  84.0  89.0  64.0
# 3         FC Barcelona  64.0  58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0
# 4     FC Bayern Munich   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      ST
# 0  92.0
# 1  88.0
# 2  84.0
# 3  88.0
# 4   NaN

# %%
gk = cldat["RB"].isnull() == True
gk_db = cldat[gk]
gk_db.head()
# Out:
#            Name  Age Nationality  Overall  Potential               Club  RB  \
# 4      M. Neuer   31     Germany       92         92   FC Bayern Munich NaN
# 6        De Gea   26       Spain       90         92  Manchester United NaN
# 12  T. Courtois   25     Belgium       89         92            Chelsea NaN
# 18    G. Buffon   39       Italy       89         89           Juventus NaN
# 20     J. Oblak   24    Slovenia       88         93    Atlético Madrid NaN
#
#     RCB  RCM  RDM  RF  RM  RS  RW  RWB  ST
# 4   NaN  NaN  NaN NaN NaN NaN NaN  NaN NaN
# 6   NaN  NaN  NaN NaN NaN NaN NaN  NaN NaN
# 12  NaN  NaN  NaN NaN NaN NaN NaN  NaN NaN
# 18  NaN  NaN  NaN NaN NaN NaN NaN  NaN NaN
# 20  NaN  NaN  NaN NaN NaN NaN NaN  NaN NaN

# %%
plyr = cldat["RB"].isnull() != True
plyr_db = cldat[plyr]
plyr_db.head()
# Out:
#                 Name  Age Nationality  Overall  Potential  \
# 0  Cristiano Ronaldo   32    Portugal       94         94
# 1           L. Messi   30   Argentina       93         93
# 2             Neymar   25      Brazil       92         94
# 3          L. Suárez   30     Uruguay       92         92
# 5     R. Lewandowski   28      Poland       91         91
#
#                   Club    RB   RCB   RCM   RDM    RF    RM    RS    RW   RWB  \
# 0       Real Madrid CF  61.0  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0
# 1         FC Barcelona  57.0  45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0
# 2  Paris Saint-Germain  59.0  46.0  79.0  59.0  88.0  87.0  84.0  89.0  64.0
# 3         FC Barcelona  64.0  58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0
# 5     FC Bayern Munich  58.0  57.0  78.0  62.0  87.0  82.0  88.0  84.0  61.0
#
#      ST
# 0  92.0
# 1  88.0
# 2  84.0
# 3  88.0
# 5  88.0

# %%
sup_dat1 = pd.read_csv("../datasets/fifa-18-demo-player-dataset/PlayerAttributeData.csv")
sup_dat1.head()
# Out:
#    Unnamed: 0 Acceleration Aggression Agility Balance Ball control Composure  \
# 0           0           89         63      89      63           93        95
# 1           1           92         48      90      95           95        96
# 2           2           94         56      96      82           95        92
# 3           3           88         78      86      60           91        83
# 4           4           58         29      52      35           48        70
#
#   Crossing Curve Dribbling   ...   Reactions Short passing Shot power  \
# 0       85    81        91   ...          96            83         94
# 1       77    89        97   ...          95            88         85
# 2       75    81        96   ...          88            81         80
# 3       77    86        86   ...          93            83         87
# 4       15    14        30   ...          85            55         25
#
#   Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision Volleys
# ...

# %%
sup_dat2 = pd.read_csv("../datasets/fifa-18-demo-player-dataset/PlayerPersonalData.csv")
sup_dat2.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      ID               Name  Age  \
# 0           0             0   20801  Cristiano Ronaldo   32
# 1           1             1  158023           L. Messi   30
# 2           2             2  190871             Neymar   25
# 3           3             3  176580          L. Suárez   30
# 4           4             4  167495           M. Neuer   31
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/167495.png     Germany
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# ...

# %%
sup_dat3 = pd.read_csv("../datasets/fifa-18-demo-player-dataset/PlayerPlayingPositionData.csv")
sup_dat3.head()
# Out:
#    Unnamed: 0   CAM    CB   CDM    CF    CM      ID   LAM    LB   LCB  ...   \
# 0           0  89.0  53.0  62.0  91.0  82.0   20801  89.0  61.0  53.0  ...
# 1           1  92.0  45.0  59.0  92.0  84.0  158023  92.0  57.0  45.0  ...
# 2           2  88.0  46.0  59.0  88.0  79.0  190871  88.0  59.0  46.0  ...
# 3           3  87.0  58.0  65.0  88.0  80.0  176580  87.0  64.0  58.0  ...
# 4           4   NaN   NaN   NaN   NaN   NaN  167495   NaN   NaN   NaN  ...
#
#      RB   RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  61.0  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  57.0  45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# 2  59.0  46.0  79.0  59.0  88.0  87.0  84.0  89.0  64.0  84.0
# 3  64.0  58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 29 columns]

# %%
# helper function to see front and back of column as .head() and .tail() for row
def front(self, n):
    return self.iloc[:, :n]

def back(self, n):
    return self.iloc[:, -n:]

pd.DataFrame.front = front
pd.DataFrame.back = back

col_viewer = pd.DataFrame(sup_dat3)

# %%
col_viewer.back(20).head()
# Out:
#     LCB   LCM   LDM    LF    LM    LS    LW   LWB Preferred Positions   RAM  \
# 0  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0              ST LW   89.0
# 1  45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0                 RW   92.0
# 2  46.0  79.0  59.0  88.0  87.0  84.0  89.0  64.0                 LW   88.0
# 3  58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0                 ST   87.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN                 GK    NaN
#
#      RB   RCB   RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  61.0  53.0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# 1  57.0  45.0  84.0  59.0  92.0  90.0  88.0  91.0  62.0  88.0
# 2  59.0  46.0  79.0  59.0  88.0  87.0  84.0  89.0  64.0  84.0
# 3  64.0  58.0  80.0  65.0  88.0  85.0  88.0  87.0  68.0  88.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %%
col_viewer.front(20).head()
# Out:
#    Unnamed: 0   CAM    CB   CDM    CF    CM      ID   LAM    LB   LCB   LCM  \
# 0           0  89.0  53.0  62.0  91.0  82.0   20801  89.0  61.0  53.0  82.0
# 1           1  92.0  45.0  59.0  92.0  84.0  158023  92.0  57.0  45.0  84.0
# 2           2  88.0  46.0  59.0  88.0  79.0  190871  88.0  59.0  46.0  79.0
# 3           3  87.0  58.0  65.0  88.0  80.0  176580  87.0  64.0  58.0  80.0
# 4           4   NaN   NaN   NaN   NaN   NaN  167495   NaN   NaN   NaN   NaN
#
#     LDM    LF    LM    LS    LW   LWB Preferred Positions   RAM    RB
# 0  62.0  91.0  89.0  92.0  91.0  66.0              ST LW   89.0  61.0
# 1  59.0  92.0  90.0  88.0  91.0  62.0                 RW   92.0  57.0
# 2  59.0  88.0  87.0  84.0  89.0  64.0                 LW   88.0  59.0
# 3  65.0  88.0  85.0  88.0  87.0  68.0                 ST   87.0  64.0
# 4   NaN   NaN   NaN   NaN   NaN   NaN                 GK    NaN   NaN
